# %% [markdown]
# # 1

# %%
# isi fungsi python yang tepat agar bisa menghasilkan output
...("hello world")

# %%
print("hello world")
# Out:
# hello world

# %% [markdown]
# # 2

# %%
# buatkan sebuah variabel yang bernama benda
# isi variabel tersebut dengan string "kursi"
# print variabel tersebut
... = ...
...

# %%
# Buat variabel bernama benda dan isi dengan string "kursi"
benda = "kursi"
# Print variabel tersebut
print(benda)
# Out:
# kursi

# %% [markdown]
# # 3

# %%
# periksa tipe data pada variabel var
var = "buah"
...

# %%
# Periksa tipe data pada variabel var
var = "buah"
print(type(var))
# Out:
# <class 'str'>

# %% [markdown]
# # 4

# %%
# ganti nilai temperatur menjadi 30, lalu print nilai temperatur
temperatur = 20
...
...

# %%
# Ganti nilai temperatur menjadi 30, lalu print nilai temperatur
temperatur = 20
temperatur = 30
print(temperatur)
# Out:
# 30

# %% [markdown]
# # 5

# %%
# buatkan sebuah list yang berisi 5 nama buah
# lalu print nama buah yang berada pada index ke-3
... = ...
...

# %%
# Buatkan sebuah list yang berisi 5 nama buah
buah = ["apel", "jeruk", "pisang", "mangga", "anggur"]

# Lalu print nama buah yang berada di index ke-3 (index 3 = elemen ke-4, yaitu mangga)
print(buah[3])
# Out:
# mangga

# %% [markdown]
# # 6

# %%
# diberikan variabel suhu dengan nilai 27
# periksa apakah temperatur lebih dari 25, jika ya, print "panas", jika tidak, print "dingin"
suhu = 27
if ...:
    print(...)
else:
    print(...)

# %%
# Diberikan variabel suhu dengan nilai 27
suhu = 27
# Periksa apakah temperatur lebih dari 25, jika ya, print "panas", jika tidak, print "dingin"
if suhu > 25:
    print("panas")
else:
    print("dingin")
# Out:
# panas

# %% [markdown]
# # 7

# %%
# terdapat variabel judul dengan semua huruf kecil
# ubahlah judul tersebut menjadi semua hurufnya kapital
judul = "belajar python"
...
...

# %%
# Terdapat variabel judul dengan semua huruf kecil
judul = "belajar python"
# Ubah judul tersebut menjadi semua hurufnya kapital
judul = judul.upper()
print(judul)
# Out:
# BELAJAR PYTHON
